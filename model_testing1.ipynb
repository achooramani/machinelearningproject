# %%
# Read data

data = read.csv("/Volumes/UBC/Block6/586-AdvanceMachineLearning/project/machinelearningproject/data/processed_data/HDFS/HDFS_2k_structured.csv, header = TRUE")
# Out:
# Warning message in file(file, "rt"):
# “cannot open file '/Volumes/UBC/Block6/586-AdvanceMachineLearning/project/machinelearningproject/data/processed_data/HDFS/HDFS_2k_structured.csv, header = TRUE': No such file or directory”
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. read.csv("/Volumes/UBC/Block6/586-AdvanceMachineLearning/project/machinelearningproject/data/processed_data/HDFS/HDFS_2k_structured.csv, header = TRUE")
# 2. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)
# 3. file(file, "rt")

# %%
set.seed(2402)
dt = sort(sample(nrow(data), nrow(data)*.8), replace = FALSE)
train<-data[dt,]
test<-data[-dt,]
# Out:
# Error in sort.int(x, na.last = na.last, decreasing = decreasing, ...): unused argument (replace = FALSE)
# Traceback:
#
# 1. sort(sample(nrow(data), nrow(data) * 0.8), replace = FALSE)
# 2. sort.default(sample(nrow(data), nrow(data) * 0.8), replace = FALSE)

# %%
# Out:
#      Date       Time   PID   Level Component
# 1    2008-11-09 203615  148  INFO  dfs.DataNode$PacketResponder
# 3    2008-11-09 204005   35  INFO  dfs.FSNamesystem
# 4    2008-11-09 204015  308  INFO  dfs.DataNode$PacketResponder
# 5    2008-11-09 204106  329  INFO  dfs.DataNode$PacketResponder
# 6    2008-11-09 204132   26  INFO  dfs.FSNamesystem
# 8    2008-11-09 204453   34  INFO  dfs.FSNamesystem
# 9    2008-11-09 204525  512  INFO  dfs.DataNode$PacketResponder
# 10   2008-11-09 204655  556  INFO  dfs.DataNode$PacketResponder
# 11   2008-11-09 204722  567  INFO  dfs.DataNode$PacketResponder
# 12   2008-11-09 204815  653  INFO  dfs.DataNode$DataXceiver
# 13   2008-11-09 204842  663  INFO  dfs.DataNode$DataXceiver
# 16   2008-11-09 205035   28  INFO  dfs.FSNamesystem
# 17   2008-11-09 205056  710  INFO  dfs.DataNode$PacketResponder
# 19   2008-11-09 205315   29  INFO  dfs.FSNamesystem
# 20   2008-11-09 205409   28  INFO  dfs.FSNamesystem
# ...
